# %%
import pandas

# %%
data = pandas.read_excel("C:\\Users\\Agne\\Desktop\\PythonCourse\\Homework\\Untitled Folder\\P_Data_Extract_From_Gender_Statistics (1) 1.xlsx")

# %%
data
# Out:
#               Country Name Country Code
# 0                  Estonia          EST  \
# 1                   Latvia          LVA
# 2                Lithuania          LTU
# 3                  Albania          ALB
# 4                  Andorra          AND
# 5                  Armenia          ARM
# 6                  Austria          AUT
# 7               Azerbaijan          AZE
# 8                  Belarus          BLR
# 9                  Belgium          BEL
# 10  Bosnia and Herzegovina          BIH
# 11                Bulgaria          BGR
# 12         Channel Islands          CHI
# 13                 Croatia          HRV
# 14                  Cyprus          CYP
# 15                 Czechia          CZE
# 16                 Denmark          DNK
# 17           Faroe Islands          FRO
# 18                 Finland          FIN
# 19                  France          FRA
# 20                 Georgia          GEO
# 21                 Germany          DEU
# ...

# %%
data1 = data.loc[data["Female share of employment in senior and middle management (%), 2017"] != '..' ]
data1
# Out:
#               Country Name Country Code
# 0                  Estonia          EST  \
# 1                   Latvia          LVA
# 2                Lithuania          LTU
# 3                  Albania          ALB
# 6                  Austria          AUT
# 8                  Belarus          BLR
# 9                  Belgium          BEL
# 10  Bosnia and Herzegovina          BIH
# 11                Bulgaria          BGR
# 13                 Croatia          HRV
# 14                  Cyprus          CYP
# 15                 Czechia          CZE
# 16                 Denmark          DNK
# 18                 Finland          FIN
# 19                  France          FRA
# 20                 Georgia          GEO
# 21                 Germany          DEU
# 23                  Greece          GRC
# 25                 Hungary          HUN
# 26                 Iceland          ISL
# 27                 Ireland          IRL
# 29                   Italy          ITA
# ...

# %%
data2 = data1.loc[data1["Female share of graduates from Science, Technology, Engineering and Mathematics (STEM) programmes, tertiary (%), 2017"] != '..' ]
data2
# Out:
#               Country Name Country Code
# 0                  Estonia          EST  \
# 1                   Latvia          LVA
# 2                Lithuania          LTU
# 3                  Albania          ALB
# 8                  Belarus          BLR
# 9                  Belgium          BEL
# 10  Bosnia and Herzegovina          BIH
# 11                Bulgaria          BGR
# 13                 Croatia          HRV
# 14                  Cyprus          CYP
# 15                 Czechia          CZE
# 16                 Denmark          DNK
# 18                 Finland          FIN
# 20                 Georgia          GEO
# 21                 Germany          DEU
# 23                  Greece          GRC
# 25                 Hungary          HUN
# 32         Kyrgyz Republic          KGZ
# 38             Netherlands          NLD
# 39         North Macedonia          MKD
# 40                  Norway          NOR
# 41                  Poland          POL
# ...

# %%
data2["Female share of employment in senior and middle management (%), 2017"].mean()
# Out:
# 31.893103500892373

# %%
data2["Female share of graduates from Science, Technology, Engineering and Mathematics (STEM) programmes, tertiary (%), 2017"].mean()
# Out:
# 35.1077524137931

# %%
data2["Female share of employment in senior and middle management (%), 2017"].median()
# Out:
# 30.8999996185303

# %%
data2["Female share of graduates from Science, Technology, Engineering and Mathematics (STEM) programmes, tertiary (%), 2017"].median()
# Out:
# 35.47829

# %%
data2["Female share of employment in senior and middle management (%), 2017"].std()
# Out:
# 6.976385225599483

# %%
data2["Female share of graduates from Science, Technology, Engineering and Mathematics (STEM) programmes, tertiary (%), 2017"].std()
# Out:
# 6.676513638109475

# %%
import matplotlib.pyplot as pl

# %%
import numpy as np

# %%
pl.scatter(data2["Female share of employment in senior and middle management (%), 2017"],data2["Female share of graduates from Science, Technology, Engineering and Mathematics (STEM) programmes, tertiary (%), 2017"])
pl.xlabel("Female share of employment in senior and middle management (%), 2017")
pl.ylabel("Female share of graduates from Science, Technology, Engineering and Mathematics (STEM) programmes, tertiary (%), 2017")
# Out:
# Text(0, 0.5, 'Female share of graduates from Science, Technology, Engineering and Mathematics (STEM) programmes, tertiary (%), 2017')

# %%
data2.groupby(["Female share of graduates from Science, Technology, Engineering and Mathematics (STEM) programmes, tertiary (%), 2017"]).min(data2["Female share of graduates from Science, Technology, Engineering and Mathematics (STEM) programmes, tertiary (%), 2017"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 data2.groupby(["Female share of graduates from Science, Technology, Engineering and Mathematics (STEM) programmes, tertiary (%), 2017"]).min(data2["Female share of graduates from Science, Technology, Engineering and Mathematics (STEM) programmes, tertiary (%), 2017"])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:2293, in GroupBy.min(self, numeric_only, min_count, engine, engine_kwargs)
#    2291     return self._numba_agg_general(sliding_min_max, engine_kwargs, False)
#    2292 else:
# -> 2293     return self._agg_general(
#    2294         numeric_only=numeric_only,
#    2295         min_count=min_count,
#    2296         alias="min",
#    2297         npfunc=np.min,
#    2298     )
#
# ...
