# %%
import pandas

# %%
data = pandas.read_excel("C:\\Users\\Agne\\Desktop\\PythonCourse\\Homework\\finalproject\\P_Data_Extract_From_Gender_Statistics (2).xlsx")
data
# Out:
#                                Series Name     Series Code Country Name
# 0             GDP per capita (Current US$)  NY.GDP.PCAP.CD      Albania  \
# 1             GDP per capita (Current US$)  NY.GDP.PCAP.CD      Andorra
# 2             GDP per capita (Current US$)  NY.GDP.PCAP.CD      Armenia
# 3             GDP per capita (Current US$)  NY.GDP.PCAP.CD      Austria
# 4             GDP per capita (Current US$)  NY.GDP.PCAP.CD   Azerbaijan
# ..                                     ...             ...          ...
# 116                                    NaN             NaN          NaN
# 117                                    NaN             NaN          NaN
# 118                                    NaN             NaN          NaN
# 119  Data from database: Gender Statistics             NaN          NaN
# 120               Last Updated: 05/12/2023             NaN          NaN
#
#     Country Code  2015 [YR2015]  2016 [YR2016]  2017 [YR2017]
# ...

# %%
data = data.drop(index=[116,117,118,119,120])
data
# Out:
#                                            Series Name           Series Code
# 0                         GDP per capita (Current US$)        NY.GDP.PCAP.CD  \
# 1                         GDP per capita (Current US$)        NY.GDP.PCAP.CD
# 2                         GDP per capita (Current US$)        NY.GDP.PCAP.CD
# 3                         GDP per capita (Current US$)        NY.GDP.PCAP.CD
# 4                         GDP per capita (Current US$)        NY.GDP.PCAP.CD
# ..                                                 ...                   ...
# 111  Female share of graduates from Science, Techno...  SE.TER.GRAD.FE.SI.ZS
# 112  Female share of graduates from Science, Techno...  SE.TER.GRAD.FE.SI.ZS
# 113  Female share of graduates from Science, Techno...  SE.TER.GRAD.FE.SI.ZS
# 114  Female share of graduates from Science, Techno...  SE.TER.GRAD.FE.SI.ZS
# 115  Female share of graduates from Science, Techno...  SE.TER.GRAD.FE.SI.ZS
#
# ...

# %%
data = data.drop(columns='Series Code')
data = data.round(1)
data = data.loc[data["2015 [YR2015]"] != 0.0 ]
data
# Out:
#                                            Series Name    Country Name
# 0                         GDP per capita (Current US$)         Albania  \
# 1                         GDP per capita (Current US$)         Andorra
# 2                         GDP per capita (Current US$)         Armenia
# 3                         GDP per capita (Current US$)         Austria
# 4                         GDP per capita (Current US$)      Azerbaijan
# ..                                                 ...             ...
# 111  Female share of graduates from Science, Techno...         Turkiye
# 112  Female share of graduates from Science, Techno...    Turkmenistan
# 113  Female share of graduates from Science, Techno...         Ukraine
# 114  Female share of graduates from Science, Techno...  United Kingdom
# 115  Female share of graduates from Science, Techno...      Uzbekistan
#
#     Country Code  2015 [YR2015]  2016 [YR2016]  2017 [YR2017]
# ...

# %%
data1 = data.pivot(index=['Country Name', 'Country Code'],
                       columns=['2015 [YR2015]','2016 [YR2016]','2017 [YR2017]'], values=['Series Name'])
data1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 data1 = data.pivot(index=['Country Name', 'Country Code'],
#       2                        columns=['2015 [YR2015]','2016 [YR2016]','2017 [YR2017]'], values=['Series Name'])
#       3 data1
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:8419, in DataFrame.pivot(self, columns, index, values)
#    8414 @Substitution("")
#    8415 @Appender(_shared_docs["pivot"])
#    8416 def pivot(self, *, columns, index=lib.NoDefault, values=lib.NoDefault) -> DataFrame:
#    8417     from pandas.core.reshape.pivot import pivot
# -> 8419     return pivot(self, index=index, columns=columns, values=values)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\pivot.py:555, in pivot(data, columns, index, values)
# ...

# %%
data2 = data1.dropna()

# %%
data2
# Out:
#                                                                                                                                       2015 [YR2015]
# Series Name                         Female share of graduates from Science, Technology, Engineering and Mathematics (STEM) programmes, tertiary (%)
# Country Name           Country Code
# Albania                ALB                                                        52.8                                                               \
# Armenia                ARM                                                        42.8
# Azerbaijan             AZE                                                        33.4
# Belarus                BLR                                                        26.3
# Belgium                BEL                                                        26.6
# Bosnia and Herzegovina BIH                                                        42.6
# ...

# %%
fstem2015mean = data2["2015 [YR2015]","Female share of graduates from Science, Technology, Engineering and Mathematics (STEM) programmes, tertiary (%)"].mean()

# %%
fstem2016mean = data2["2016 [YR2016]","Female share of graduates from Science, Technology, Engineering and Mathematics (STEM) programmes, tertiary (%)"].mean()

# %%
fstem2017mean = data2["2017 [YR2017]","Female share of graduates from Science, Technology, Engineering and Mathematics (STEM) programmes, tertiary (%)"].mean()

# %%
fstemyearmean = [fstem2015mean, fstem2016mean, fstem2017mean]

# %%
years = ["2015","2016","2017"]

# %%
import matplotlib.pyplot as pl
import numpy as np

# %%
data2.loc['Mean'] = data2.mean()
data2
# Out:
# C:\Users\Agne\AppData\Local\Temp\ipykernel_17376\616621251.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2.loc['Mean'] = data2.mean()
#                                                                                                                                 2015 [YR2015]
# Series Name                   Female share of graduates from Science, Technology, Engineering and Mathematics (STEM) programmes, tertiary (%)
# (Albania, ALB)                                                         52.800000                                                               \
# (Armenia, ARM)                                                         42.800000
# (Azerbaijan, AZE)                                                      33.400000
# ...

# %%
data_stem = data2[[('2015 [YR2015]','Female share of graduates from Science, Technology, Engineering and Mathematics (STEM) programmes, tertiary (%)'),
                   ('2016 [YR2016]','Female share of graduates from Science, Technology, Engineering and Mathematics (STEM) programmes, tertiary (%)'),
                  ('2017 [YR2017]','Female share of graduates from Science, Technology, Engineering and Mathematics (STEM) programmes, tertiary (%)')]]

# %%
data_stem
# Out:
#                                                                                                                                 2015 [YR2015]
# Series Name                   Female share of graduates from Science, Technology, Engineering and Mathematics (STEM) programmes, tertiary (%)
# (Albania, ALB)                                                         52.800000                                                               \
# (Armenia, ARM)                                                         42.800000
# (Azerbaijan, AZE)                                                      33.400000
# (Belarus, BLR)                                                         26.300000
# (Belgium, BEL)                                                         26.600000
# (Bosnia and Herzegovina, BIH)                                          42.600000
# (Bulgaria, BGR)                                                        37.500000
# ...

# %%
data_stem_mean = data_stem.mean(axis=1)

# %%
data_stem_mean.to_list()
# Out:
# [49.9,
#  37.46666666666666,
#  36.099999999999994,
#  26.666666666666668,
#  26.633333333333336,
#  43.13333333333333,
#  37.56666666666666,
#  37.333333333333336,
#  40.5,
#  35.166666666666664,
#  33.36666666666667,
#  39.06666666666666,
#  27.366666666666664,
#  27.166666666666668,
#  31.633333333333336,
#  32.666666666666664,
#  31.46666666666667,
#  30.066666666666666,
#  28.666666666666668,
#  43.699999999999996,
#  38.63333333333333,
#  40.300000000000004,
#  29.53333333333333,
#  34.833333333333336,
#  22.366666666666664,
#  28.866666666666664,
#  34.23717948717948]

# %%
data_gdp = data2[[('2015 [YR2015]','GDP per capita (Current US$)'),
                   ('2016 [YR2016]','GDP per capita (Current US$)'),
                  ('2017 [YR2017]','GDP per capita (Current US$)')]]

# %%
data_gdp
# Out:
#                                              2015 [YR2015]
# Series Name                   GDP per capita (Current US$)
# (Albania, ALB)                                 3952.800000  \
# (Armenia, ARM)                                 3666.100000
# (Azerbaijan, AZE)                              5500.300000
# (Belarus, BLR)                                 5967.100000
# (Belgium, BEL)                                41008.300000
# (Bosnia and Herzegovina, BIH)                  4599.900000
# (Bulgaria, BGR)                                7074.700000
# (Croatia, HRV)                                11952.300000
# (Cyprus, CYP)                                 23487.100000
# (Czechia, CZE)                                17829.700000
# (Denmark, DNK)                                53254.900000
# (Estonia, EST)                                17402.000000
# (Finland, FIN)                                42801.900000
# (Germany, DEU)                                41103.300000
# ...

# %%
data_gdp_mean = data_gdp.mean(axis=1)

# %%
data_gdp_mean.to_list()
# Out:
# [4202.633333333334,
#  3796.0333333333333,
#  4509.366666666667,
#  5597.5,
#  42406.46666666667,
#  4904.833333333333,
#  7670.166666666667,
#  12720.133333333331,
#  24966.666666666668,
#  19013.7,
#  55176.333333333336,
#  18711.7,
#  44342.666666666664,
#  42630.666666666664,
#  13480.966666666667,
#  1161.5333333333335,
#  14604.466666666667,
#  15385.9,
#  73437.63333333335,
#  12918.166666666666,
#  20244.166666666668,
#  5882.233333333334,
#  26825.633333333335,
#  52434.06666666667,
#  82737.96666666666,
#  2316.9,
#  23541.48076923077]

# %%
data2["Mean of female share of graduates from STEM programmes, tertiary (%)"] = data_stem_mean.to_list()
data2["Mean GDP per capita (Current US$)"] = data_gdp_mean.to_list()
# Out:
# C:\Users\Agne\AppData\Local\Temp\ipykernel_17376\2822061274.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2["Mean of female share of graduates from STEM programmes, tertiary (%)"] = data_stem_mean.to_list()
# C:\Users\Agne\AppData\Local\Temp\ipykernel_17376\2822061274.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2["Mean GDP per capita (Current US$)"] = data_gdp_mean.to_list()

# %%
data2
# Out:
#                                                                                                                                 2015 [YR2015]
# Series Name                   Female share of graduates from Science, Technology, Engineering and Mathematics (STEM) programmes, tertiary (%)
# (Albania, ALB)                                                         52.800000                                                               \
# (Armenia, ARM)                                                         42.800000
# (Azerbaijan, AZE)                                                      33.400000
# (Belarus, BLR)                                                         26.300000
# (Belgium, BEL)                                                         26.600000
# (Bosnia and Herzegovina, BIH)                                          42.600000
# (Bulgaria, BGR)                                                        37.500000
# ...

# %%
data2.round(1)
# Out:
#                                                                                                                                 2015 [YR2015]
# Series Name                   Female share of graduates from Science, Technology, Engineering and Mathematics (STEM) programmes, tertiary (%)
# (Albania, ALB)                                                              52.8                                                               \
# (Armenia, ARM)                                                              42.8
# (Azerbaijan, AZE)                                                           33.4
# (Belarus, BLR)                                                              26.3
# (Belgium, BEL)                                                              26.6
# (Bosnia and Herzegovina, BIH)                                               42.6
# (Bulgaria, BGR)                                                             37.5
# ...
